# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Gerardo Ruiz Velasco Lazalde y Dayana Navarro Valencia
#
# **Fecha:** 17 de octubre del 2020.
#
# **Expediente** : if721470 .
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# ### Link de Github:
#
# # Tarea 3: Clase 6. NumerosPseudoaleatorios

# %% [markdown]
# ## Enunciado de tarea
# > Usando compresión de listas o funciones map(sino recuerda como funciona observar el siguiente enlace https://www.pythonforbeginners.com/lists/list-comprehensions-in-python/), resolver los siguientes ejercicios:
#
# >1. Resolver la siguiente ecuación recursiva usando funciones como se vió en clase
# $$ D_{n}=(n-1) D_{n-1}+(n-1) D_{n-2} \quad n\ge 3$$
# con $D_1=0$ y $D_2 = 1$
# >3. Count the number of spaces in the following string `variable =  relaciónn  requiere,  para obtener  el  valor  de un  cierto  término,  el conocimiento de los dos anteriores`.
# >4. Remove all of the vowels in a string [make a list of the non-vowels].
# >5. Find all of the words in a string that are less than 4 letters.
# >6. Use a dictionary comprehension to count the length of each word in a sentence.
# >7. Use a nested list comprehension to find all of the numbers from 1-1000 that are divisible by any single digit besides 1 (2-9).

# %% [markdown]
# ### Ejercicio 1: Resolver la siguiente ecuación recursiva usando funciones como se vió en clase
# $$ D_{n}=(n-1) D_{n-1}+(n-1) D_{n-2} \quad n\ge 3$$
# con $D_1=0$ y $D_2 = 1$

# %%
# SOLUCION GERARDO

# %%
# Código de solución

# %%
# SOLUCION DAYANA

# %%
# Código de solución

# %% [markdown]
# ### Ejercicio 2: Count the number of spaces in the following string `variable =  relaciónn  requiere,  para obtener  el  valor  de un  cierto  término,  el conocimiento de los dos anteriores`.

# %%
# SOLUCION GERARDO

# %%
# Código de solución

# %%
# SOLUCION DAYANA

# %%
# Código de solución

# %% [markdown]
# ### Ejercicio 3: Remove all of the vowels in a string [make a list of the non-vowels]

# %%
# SOLUCION GERARDO

# %%
# Código de solución

# %%
# SOLUCION DAYANA

# %%
# Código de solución

# %% [markdown]
# ### Ejercicio 4: Find all of the words in a string that are less than 4 letters.

# %%
# SOLUCION GERARDO

# %%
# Código de solución

# %%
# SOLUCION DAYANA

# %%
# Código de solución

# %% [markdown]
# ### Ejercicio 5: Use a dictionary comprehension to count the length of each word in a sentence.

# %%
# SOLUCION GERARDO

# %%
# Código de solución

# %%
# SOLUCION DAYANA

# %%
# Código de solución

# %% [markdown]
# ### Ejercicio 6: Use a nested list comprehension to find all of the numbers from 1-1000 that are divisible by any single digit besides 1 (2-9).

# %%
# SOLUCION GERARDO

# %%
# Código de solución

# %%
# SOLUCION DAYANA

# %%
# Código de solución
